# %%
# %pip install pdfplumber pytesseract pdf2image
# Out:
# Requirement already satisfied: pdfplumber in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (0.11.9)
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pdfminer.six==20251230 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (5.3.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (46.0.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pytesseract) (24.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.22)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pytesseract, pdf2image
#
#    ---------------------------------------- 0/2 [pytesseract]
#    ---------------------------------------- 0/2 [pytesseract]
#    ---------------------------------------- 2/2 [pdf2image]
#
# Successfully installed pdf2image-1.17.0 pytesseract-0.3.13
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        # Try direct text extraction
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        if text.strip():
            return text.strip()
    except Exception as e:
        print(f"Direct text extraction failed: {e}")

    # Fallback to OCR for image-based PDFs
    print("Falling back to OCR for image-based PDF.")
    try:
        images = convert_from_path(pdf_path)
        for image in images:
            page_text = pytesseract.image_to_string(image)
            text += page_text + "\n"
    except Exception as e:
        print(f"OCR failed: {e}")

    return text.strip()

# %%
pdf_path = "Resume.pdf"
resume_text = extract_text_from_pdf(pdf_path)

print("\nExtracted Text from PDF:")
print(resume_text)
# Out:
# Direct text extraction failed: [Errno 2] No such file or directory: 'Resume.pdf'
# Falling back to OCR for image-based PDF.
# OCR failed: Unable to get page count. Is poppler installed and in PATH?
#
# Extracted Text from PDF:

# %% [markdown]
# ## Set GROQ Api Key

# %%
# !pip install langchain-groq python-dotenv
# Out:
# Requirement already satisfied: langchain-groq in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dotenv in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (1.1.0)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-groq) (0.31.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-groq) (1.2.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.3.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (24.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (1.1.1)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-groq) (0.31.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-groq) (1.2.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.3.45)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (24.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mansi\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq

# Define API key directly in the notebook cell (Jupyter use-case)
GROQ_API_KEY = "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"

# Initialize ChatGroq model
llm = ChatGroq(
    api_key=GROQ_API_KEY,
    model="llama-3.1-8b-instant",
    temperature=0
)

# Invoke the model
response = llm.invoke("explain langchain in one line?")

# Print only the model output text
print(response.content)
# Out:
# LangChain is an open-source framework that enables developers to build, train, and deploy large language models (LLMs) and other AI models, allowing for the creation of custom conversational AI applications.

# %% [markdown]
# ## Resume Analyse

# %%
from langchain_groq import ChatGroq

# Define API key directly (Jupyter use-case)
GROQ_API_KEY = "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"

def analyze_resume(resume_text, job_description=None):
    if not resume_text:
        return {"error": "Resume text is required for analysis."}
    
    # Initialize Groq LLM
    model = ChatGroq(
        api_key=GROQ_API_KEY,
        model="llama-3.1-8b-instant",
        temperature=0
    )
    
    base_prompt = f"""
    You are an experienced HR with Technical Experience in the field of any one job role from Data Science, Data Analyst, DevOPS, Machine Learning Engineer, Prompt Engineer, AI Engineer, Full Stack Web Development, Big Data Engineering, Marketing Analyst, Human Resource Manager, Software Developer your task is to review the provided resume.
    Please share your professional evaluation on whether the candidate's profile aligns with the role.ALso mention Skills he already have and siggest some skills to imorve his resume , alos suggest some course he might take to improve the skills.Highlight the strengths and weaknesses.

    Resume:
    {resume_text}
    """

    if job_description:
        base_prompt += f"""
        Additionally, compare this resume to the following job description:
        
        Job Description:
        {job_description}
        
        Highlight the strengths and weaknesses of the applicant in relation to the specified job requirements.
        """

    # Invoke Groq model
    response = model.invoke(base_prompt)

    analysis = response.content.strip()
    return analysis

# %%
print(analyze_resume(resume_text))
# Out:
# {'error': 'Resume text is required for analysis.'}
